# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Task:1. Scalar & Array Operations (Redo Section with Your Own Values)

# %%
# Sample scalar and array inputs
scalar = 3.7
arr = np.array([1, 2, 3, 4, 5,6])

# Trigonometric functions
sin_values = np.sin(arr)
cos_values = np.cos(arr)
tan_values = np.tan(arr)
asin_values = np.arcsin(np.clip(arr / np.max(arr), -1, 1))  # Normalized and Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(arr / np.max(arr), -1, 1))
atan_values = np.arctan(arr)

# Exponential and logarithm
exp_values = np.exp(arr)
log_values = np.log(arr)  # Natural logarithm

# Absolute value and square root
abs_values = np.abs(arr)
sqrt_values = np.sqrt(arr)

# Remainder when divided by a scalar (e.g., 2)
rem_values = np.remainder(arr, 2)

# Rounding functions
round_values = np.round(arr)
floor_values = np.floor(arr)
ceil_values = np.ceil(arr)

# Display results
print("sin:", sin_values)
print("cos:", cos_values)
print("tan:", tan_values)
print("asin:", asin_values)
print("acos:", acos_values)
print("atan:", atan_values)
print("exp:", exp_values)
print("log:", log_values)
print("abs:", abs_values)
print("sqrt:", sqrt_values)
print("rem:", rem_values)
print("round:", round_values)
print("floor:", floor_values)
print("ceil:", ceil_values)
# Out:
# sin: [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427 -0.2794155 ]
# cos: [ 0.54030231 -0.41614684 -0.9899925  -0.65364362  0.28366219  0.96017029]
# tan: [ 1.55740772 -2.18503986 -0.14254654  1.15782128 -3.38051501 -0.29100619]
# asin: [0.16744808 0.33983691 0.52359878 0.72972766 0.98511078 1.57079633]
# acos: [1.40334825 1.23095942 1.04719755 0.84106867 0.58568554 0.        ]
# atan: [0.78539816 1.10714872 1.24904577 1.32581766 1.37340077 1.40564765]
# exp: [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591
#  403.42879349]
# log: [0.         0.69314718 1.09861229 1.38629436 1.60943791 1.79175947]
# abs: [1 2 3 4 5 6]
# sqrt: [1.         1.41421356 1.73205081 2.         2.23606798 2.44948974]
# rem: [1 0 1 0 1 0]
# round: [1 2 3 4 5 6]
# floor: [1. 2. 3. 4. 5. 6.]
# ceil: [1. 2. 3. 4. 5. 6.]

# %% [markdown]
# # Task.2: Operations on a 3×2 Matrix.

# %%
# Creating a 3x2 matrix
matrix = np.array([[8, 4], [3, 9], [2, 5]])

# Trigonometric functions
sin_values = np.sin(matrix)
cos_values = np.cos(matrix)
tan_values = np.tan(matrix)
asin_values = np.arcsin(np.clip(matrix / np.max(matrix), -1, 1))  # Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(matrix / np.max(matrix), -1, 1))
atan_values = np.arctan(matrix)

# Exponential and logarithm
exp_values = np.exp(matrix)
log_values = np.log(matrix)  # Natural logarithm (log base e)

# Absolute value and square root
abs_values = np.abs(matrix)
sqrt_values = np.sqrt(matrix)

# Remainder when divided by 2
rem_values = np.remainder(matrix, 2)

# Rounding functions
round_values = np.round(matrix)
floor_values = np.floor(matrix)
ceil_values = np.ceil(matrix)

# Display results
print("Matrix (3x2):\n", matrix)
print("\nsin:\n", sin_values)
print("\ncos:\n", cos_values)
print("\ntan:\n", tan_values)
print("\nasine:\n", asin_values)
print("\nacosine:\n", acos_values)
print("\natangent:\n", atan_values)
print("\nexp:\n", exp_values)
print("\nlog (natural):\n", log_values)
print("\nabs:\n", abs_values)
print("\nsqrt:\n", sqrt_values)
print("\nrem (remainder when divided by 2):\n", rem_values)
print("\nround:\n", round_values)
print("\nfloor:\n", floor_values)
print("\nceil:\n", ceil_values)
# Out:
# Matrix (3x2):
#  [[8 4]
#  [3 9]
#  [2 5]]
#
# sin:
#  [[ 0.98935825 -0.7568025 ]
#  [ 0.14112001  0.41211849]
#  [ 0.90929743 -0.95892427]]
#
# cos:
#  [[-0.14550003 -0.65364362]
#  [-0.9899925  -0.91113026]
#  [-0.41614684  0.28366219]]
#
# tan:
#  [[-6.79971146  1.15782128]
#  [-0.14254654 -0.45231566]
#  [-2.18503986 -3.38051501]]
#
# asine:
#  [[1.09491408 0.46055399]
#  [0.33983691 1.57079633]
#  [0.22409309 0.58903097]]
#
# acosine:
#  [[0.47588225 1.11024234]
#  [1.23095942 0.        ]
#  [1.34670323 0.98176536]]
#
# atangent:
#  [[1.44644133 1.32581766]
#  [1.24904577 1.46013911]
#  [1.10714872 1.37340077]]
#
# exp:
#  [[2.98095799e+03 5.45981500e+01]
#  [2.00855369e+01 8.10308393e+03]
#  [7.38905610e+00 1.48413159e+02]]
#
# log (natural):
#  [[2.07944154 1.38629436]
#  [1.09861229 2.19722458]
#  [0.69314718 1.60943791]]
#
# abs:
#  [[8 4]
#  [3 9]
#  [2 5]]
#
# sqrt:
#  [[2.82842712 2.        ]
#  [1.73205081 3.        ]
#  [1.41421356 2.23606798]]
#
# rem (remainder when divided by 2):
#  [[0 0]
#  [1 1]
#  [0 1]]
#
# round:
#  [[8 4]
#  [3 9]
#  [2 5]]
#
# floor:
#  [[8. 4.]
#  [3. 9.]
#  [2. 5.]]
#
# ceil:
#  [[8. 4.]
#  [3. 9.]
#  [2. 5.]]

# %% [markdown]
# # Task.3:Vector Functions Applied to a 2×3 Matrix.

# %%
# Creating a 2x3 matrix with float values
matrix = np.array([[2.1, 4.7, 1.3],
                    [8.5, 3.9, 6.2]])

# Max & Min (with indices)
max_value = np.max(matrix)
min_value = np.min(matrix)
max_index = np.unravel_index(np.argmax(matrix), matrix.shape)
min_index = np.unravel_index(np.argmin(matrix), matrix.shape)

# Vector length (norm) - treating flattened matrix as a vector
vector_length = np.linalg.norm(matrix)

# Sorted versions
row_sorted_desc = -np.sort(-matrix, axis=1)   # row-wise descending
full_sorted_desc = np.sort(matrix.flatten())[::-1]  # entire matrix descending

# Sum and Product
sum_value = np.sum(matrix)
product_value = np.prod(matrix)

# Median, Mean, Standard Deviation
median_value = np.median(matrix)
mean_value = np.mean(matrix)
std_value = np.std(matrix)

# Display results
print("\nMax value:", max_value, "at index", max_index)
print("Min value:", min_value, "at index", min_index)
print("\nVector length (norm):", vector_length)
print("\nRow-wise sorted (descending):\n", row_sorted_desc)
print("\nEntire matrix sorted (descending):\n", full_sorted_desc)
print("\nSum:", sum_value)
print("Product:", product_value)
print("\nMedian:", median_value)
print("Mean:", mean_value)
print("Standard Deviation:", std_value)
# Out:
# Max value: 8.5 at index (np.int64(1), np.int64(0))
# Min value: 1.3 at index (np.int64(0), np.int64(2))
#
# Vector length (norm): 12.413299319681292
#
# Row-wise sorted (descending):
#  [[4.7 2.1 1.3]
#  [8.5 6.2 3.9]]
#
# Entire matrix sorted (descending):
#  [8.5 6.2 4.7 3.9 2.1 1.3]
#
# Sum: 26.7
# Product: 2637.15543
#
# Median: 4.3
# Mean: 4.45
# Standard Deviation: 2.4246992940706416

# %% [markdown]
# ## Bonus:Visualize and Random matrix.

# %%
# Replace static inputs with randomly generated float values
matrix = np.random.uniform(low=1.0, high=10.0, size=(2, 3))

#  Visualization: Heatmap using seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(matrix, annot=True, fmt=".2f", cmap="viridis", cbar=True)
plt.title("Heatmap of Randomly Generated 2x3 Matrix")
plt.xlabel("Column Index")
plt.ylabel("Row Index")
plt.show()
